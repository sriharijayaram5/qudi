# %%
import numpy as np
from atto_device import attoDry2100

# %%
address = '192.168.1.1'
cryo = attoDry2100.Device(address)

# %%
cryo.connect()

# %%
cryo.close()

# %%
cryo.vti.getTemperature()
# Out:
# 203.247

# %%
try:
    temp = cryo.vti.getTemperature()
except:
    temp = -1
    
print(temp)
# Out:
# 208.518

# %%
cryo.condenser.getTempControlStatus()
# Out:
# True
