# %%
from telebot_router import TeleBot
bot_token = '5833065328:AAGdwFd3b3xrX0Ma9NuFBX9uz_Yb5E0ARUw'
bot= TeleBot('QAFM_bot')
bot.config['api_key'] = bot_token

# %%
# chats = [1532705674, 6340115163]
chats = [6340115163]
for id in chats:
    bot.send_message(id, f"Test")
