# %%
from hardware.thirdparty.spectrum.pyspcm import *

# %%
ensemble_list = ['seq-test-us-ens']

awg_spectrum.instance.init_all_channels()
awg_spectrum.load_triggered_multi_replay(ensemble_list, trigger_type='pos_edge_rearm', trig_level0=400, trig_level1=-200)

# %%
awg_spectrum.instance.hub.start_enable_trigger()
# Out:
# 0

# %%
awg_spectrum.instance.hub.stop()
# Out:
# 0

# %%
awg_spectrum.instance.hub.set32(SPC_M2CMD, M2CMD_CARD_ENABLETRIGGER)

# %%
awg_spectrum.instance.hub.set32(SPC_M2CMD, M2CMD_CARD_DISABLETRIGGER)

# %%
awg_spectrum.instance.reset()
# Out:
# 0

# %%
delay = 128
awg_spectrum.instance.cards[0].set32(SPC_TRIG_DELAY, delay)
awg_spectrum.instance.cards[1].set32(SPC_TRIG_DELAY, delay)
