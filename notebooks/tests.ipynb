# %%
import matplotlib.pyplot as plt
import numpy as np
plt.style.use(savelogic.mpl_qd_style)

# %%
power = np.array([0.0, 0.5,   1,    1.5,   2,     2.5,   3,     3.5,    4,      4.5,    5,      5.5,    6,      7,      10,     20,   25])
counts = np.array([127, 6247, 9541, 21621, 43176, 63180, 82615, 103223, 119938, 135359, 150424, 162933, 175484, 201634, 264876, 373326, 406736 ])
bg_counts = np.array([167, 1079,1630,3761, 7928,  11172, 15214, 19167,  20933,  23353,  26375,  30157,  32725,  37291,  53829, 77094, 95087])

# %%
plt.plot(power/2, counts-bg_counts)
plt.xlabel('Power (mW)')
plt.ylabel('Counts/s')
plt.show()
